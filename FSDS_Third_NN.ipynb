# %% [markdown]
# <a href="https://colab.research.google.com/github/Saiesh-Halshikar/CNN-and-NN/blob/main/FSDS_Third_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**The MNIST Dataset**
#
#
# MNIST: *Modified National Institute of Standards and Technology*

# %%
28*28
# Out:
# 784

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [link to the wiki page](https://en.wikipedia.org/wiki/MNIST_database)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # plotting library
# %matplotlib inline
from keras.models import Sequential
import tensorflow
from tensorflow.keras.optimizers import Adam # - Works ,RMSprop
from tensorflow.keras.utils import to_categorical, plot_model
from keras import  backend as K
from keras.layers import Dense

# %%
# import dataset
from keras.datasets import mnist


# load dataset
(x_train, y_train),(x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
# count the number of unique train labels
unique, counts = np.unique(y_train, return_counts=True)
print("Train labels: ", dict(zip(unique, counts)))



# count the number of unique test labels
unique, counts = np.unique(y_test, return_counts=True)
print("\nTest labels: ", dict(zip(unique, counts)))
# Out:
# Train labels:  {0: 5923, 1: 6742, 2: 5958, 3: 6131, 4: 5842, 5: 5421, 6: 5918, 7: 6265, 8: 5851, 9: 5949}
#
# Test labels:  {0: 980, 1: 1135, 2: 1032, 3: 1010, 4: 982, 5: 892, 6: 958, 7: 1028, 8: 974, 9: 1009}

# %%
# sample 25 mnist digits from train dataset
indexes = np.random.randint(0, x_train.shape[0], size=25)
images = x_train[indexes]
labels = y_train[indexes]


# plot the 25 mnist digits
plt.figure(figsize=(5,5))
for i in range(len(indexes)):
    plt.subplot(5, 5, i + 1)
    image = images[i]
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    
plt.show()
# plt.savefig("mnist-samples.png")
# plt.close('all')

# %%
# compute the number of labels
num_labels = len(np.unique(y_train))
num_labels
# Out:
# 10

# %%
# convert to one-hot vector
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# image dimensions (assumed square)
image_size = x_train.shape[1]
input_size = image_size * image_size
input_size
# Out:
# 784

# %%
# resize and normalize
x_train = np.reshape(x_train, [-1, input_size]) #add -1 to match new reshape with original train data.
x_train = x_train.astype('float32') / 255
x_test = np.reshape(x_test, [-1, input_size])
x_test = x_test.astype('float32') / 255

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
# network parameters
batch_size = 128
hidden_units = 256
dropout = 0.45

# %%
model = Sequential()
model.add(Dense(hidden_units, input_dim=input_size,activation = 'relu'))
model.add(Dense(hidden_units,activation = 'relu'))
model.add(Dense(num_labels, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='mlp-mnist.png', show_shapes=True)

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])

# %%
H = model.fit(x_train, y_train, epochs=20, batch_size=batch_size, validation_split=0.3) #you can specify a validation set or not (it's optional). You can add "validation_split=0.3" in case you want to add validation set.
# Out:
# Epoch 1/20
# 329/329 [==============================] - 4s 10ms/step - loss: 0.3102 - accuracy: 0.9112 - val_loss: 0.1531 - val_accuracy: 0.9563
# Epoch 2/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.1139 - accuracy: 0.9663 - val_loss: 0.1358 - val_accuracy: 0.9605
# Epoch 3/20
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0741 - accuracy: 0.9773 - val_loss: 0.0993 - val_accuracy: 0.9710
# Epoch 4/20
# 329/329 [==============================] - 4s 13ms/step - loss: 0.0493 - accuracy: 0.9853 - val_loss: 0.1045 - val_accuracy: 0.9698
# Epoch 5/20
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0357 - accuracy: 0.9887 - val_loss: 0.0958 - val_accuracy: 0.9729
# Epoch 6/20
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 0.0983 - val_accuracy: 0.9726
# Epoch 7/20
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0215 - accuracy: 0.9928 - val_loss: 0.1036 - val_accuracy: 0.9724
# Epoch 8/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 0.1186 - val_accuracy: 0.9728
# Epoch 9/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.1051 - val_accuracy: 0.9746
# Epoch 10/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.1017 - val_accuracy: 0.9763
# Epoch 11/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.1412 - val_accuracy: 0.9689
# Epoch 12/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.1326 - val_accuracy: 0.9709
# Epoch 13/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.1265 - val_accuracy: 0.9746
# Epoch 14/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0173 - accuracy: 0.9949 - val_loss: 0.1003 - val_accuracy: 0.9776
# Epoch 15/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.1144 - val_accuracy: 0.9779
# Epoch 16/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.1424 - val_accuracy: 0.9719
# Epoch 17/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.1357 - val_accuracy: 0.9748
# Epoch 18/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.1389 - val_accuracy: 0.9756
# Epoch 19/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.1315 - val_accuracy: 0.9758
# Epoch 20/20
# 329/329 [==============================] - 2s 8ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1276 - val_accuracy: 0.9776

# %%
loss, acc = model.evaluate(x_test, y_test)
print("\nTest accuracy: %.1f%%" % (100.0 * acc))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0972 - accuracy: 0.9811
#
# Test accuracy: 98.1%

# %%
loss, acc = model.evaluate(x_train, y_train)
print("\nTest accuracy: %.1f%%" % (100.0 * acc))
# Out:
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0402 - accuracy: 0.9929
#
# Test accuracy: 99.3%

# %%
import matplotlib.pyplot as plt


epochs = np.arange(0, len(H.history["loss"]))
plt.figure(figsize=(10,8))
plt.style.use("ggplot")


# plot training and validation loss
plt.style.use("ggplot")
plt.plot(epochs, H.history["loss"], label="train_loss")
plt.plot(epochs, H.history["val_loss"], label="val_loss")
plt.title("Training Vs Validation Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()

# %% [markdown]
# # Adding L2 Regualarisation

# %%
from keras.layers import Dense , Activation, Dropout
import keras


model = Sequential()
model.add(Dense(hidden_units, input_dim=input_size, kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(Activation('relu'))
model.add(Dense(hidden_units))
model.add(Activation('relu'))
model.add(Dense(num_labels))
model.add(Activation('softmax'))



model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])



H = model.fit(x_train, y_train, epochs=20, batch_size=batch_size,validation_split=0.3) #you can specify a validation set or not (it's optional). You can add "validation_split=0.3" in case you want to add validation set.
# Out:
# Epoch 1/20
# 329/329 [==============================] - 4s 9ms/step - loss: 0.4958 - accuracy: 0.9076 - val_loss: 0.3081 - val_accuracy: 0.9457
# Epoch 2/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.2366 - accuracy: 0.9612 - val_loss: 0.2104 - val_accuracy: 0.9640
# Epoch 3/20
# 329/329 [==============================] - 2s 8ms/step - loss: 0.1728 - accuracy: 0.9726 - val_loss: 0.1803 - val_accuracy: 0.9681
# Epoch 4/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1484 - accuracy: 0.9762 - val_loss: 0.1649 - val_accuracy: 0.9713
# Epoch 5/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.1362 - accuracy: 0.9784 - val_loss: 0.1734 - val_accuracy: 0.9680
# Epoch 6/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.1228 - accuracy: 0.9811 - val_loss: 0.1667 - val_accuracy: 0.9688
# Epoch 7/20
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1141 - accuracy: 0.9827 - val_loss: 0.1510 - val_accuracy: 0.9731
# Epoch 8/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.1101 - accuracy: 0.9834 - val_loss: 0.1600 - val_accuracy: 0.9695
# Epoch 9/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1068 - accuracy: 0.9838 - val_loss: 0.1620 - val_accuracy: 0.9667
# Epoch 10/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1015 - accuracy: 0.9846 - val_loss: 0.1555 - val_accuracy: 0.9711
# Epoch 11/20
# 329/329 [==============================] - 3s 10ms/step - loss: 0.0962 - accuracy: 0.9867 - val_loss: 0.1538 - val_accuracy: 0.9707
# Epoch 12/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0956 - accuracy: 0.9861 - val_loss: 0.1650 - val_accuracy: 0.9679
# Epoch 13/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0936 - accuracy: 0.9864 - val_loss: 0.1593 - val_accuracy: 0.9698
# Epoch 14/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0936 - accuracy: 0.9870 - val_loss: 0.1650 - val_accuracy: 0.9671
# Epoch 15/20
# 329/329 [==============================] - 3s 10ms/step - loss: 0.0881 - accuracy: 0.9883 - val_loss: 0.1690 - val_accuracy: 0.9644
# Epoch 16/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0863 - accuracy: 0.9879 - val_loss: 0.1422 - val_accuracy: 0.9746
# Epoch 17/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0835 - accuracy: 0.9887 - val_loss: 0.1451 - val_accuracy: 0.9734
# Epoch 18/20
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0814 - accuracy: 0.9891 - val_loss: 0.1546 - val_accuracy: 0.9704
# Epoch 19/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0819 - accuracy: 0.9893 - val_loss: 0.1479 - val_accuracy: 0.9721
# Epoch 20/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0816 - accuracy: 0.9887 - val_loss: 0.1552 - val_accuracy: 0.9705

# %%
loss, acc = model.evaluate(x_test, y_test)
print("\nTest accuracy: %.1f%%" % (100.0 * acc))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1337 - accuracy: 0.9742
#
# Test accuracy: 97.4%

# %%
loss, acc = model.evaluate(x_train, y_train)
print("\nTest accuracy: %.1f%%" % (100.0 * acc))
# Out:
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1023 - accuracy: 0.9837
#
# Test accuracy: 98.4%

# %%
import matplotlib.pyplot as plt


epochs = np.arange(0, len(H.history["loss"]))
plt.figure(figsize=(10,8))
plt.style.use("ggplot")


# plot training and validation loss
plt.style.use("ggplot")
plt.plot(epochs, H.history["loss"], label="train_loss")
plt.plot(epochs, H.history["val_loss"], label="val_loss")
plt.title("Training Vs Validation Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()

# %% [markdown]
# # Adding Dropout

# %%
from keras.layers import Dense , Activation, Dropout

# model is a 3-layer MLP with ReLU and dropout after each layer
model = Sequential()
model.add(Dense(hidden_units, input_dim=input_size))
model.add(Activation('relu'))
model.add(Dropout(dropout))
model.add(Dense(hidden_units))
model.add(Activation('relu'))
model.add(Dropout(dropout))
model.add(Dense(num_labels))
model.add(Activation('softmax'))



model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])



H = model.fit(x_train, y_train, epochs=20, batch_size=batch_size,validation_split=0.3) #you can specify a validation set or not (it's optional). You can add "validation_split=0.3" in case you want to add validation set.
# Out:
# Epoch 1/20
# 329/329 [==============================] - 4s 9ms/step - loss: 0.5044 - accuracy: 0.8438 - val_loss: 0.1854 - val_accuracy: 0.9456
# Epoch 2/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.2213 - accuracy: 0.9338 - val_loss: 0.1379 - val_accuracy: 0.9592
# Epoch 3/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.1709 - accuracy: 0.9487 - val_loss: 0.1263 - val_accuracy: 0.9634
# Epoch 4/20
# 329/329 [==============================] - 3s 10ms/step - loss: 0.1430 - accuracy: 0.9564 - val_loss: 0.1091 - val_accuracy: 0.9684
# Epoch 5/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.1275 - accuracy: 0.9610 - val_loss: 0.1122 - val_accuracy: 0.9687
# Epoch 6/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.1143 - accuracy: 0.9653 - val_loss: 0.1005 - val_accuracy: 0.9718
# Epoch 7/20
# 329/329 [==============================] - 3s 10ms/step - loss: 0.1037 - accuracy: 0.9685 - val_loss: 0.0908 - val_accuracy: 0.9735
# Epoch 8/20
# 329/329 [==============================] - 3s 10ms/step - loss: 0.0895 - accuracy: 0.9717 - val_loss: 0.0881 - val_accuracy: 0.9742
# Epoch 9/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0871 - accuracy: 0.9734 - val_loss: 0.0908 - val_accuracy: 0.9737
# Epoch 10/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0781 - accuracy: 0.9752 - val_loss: 0.0968 - val_accuracy: 0.9731
# Epoch 11/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0772 - accuracy: 0.9753 - val_loss: 0.0921 - val_accuracy: 0.9739
# Epoch 12/20
# 329/329 [==============================] - 3s 10ms/step - loss: 0.0711 - accuracy: 0.9772 - val_loss: 0.0883 - val_accuracy: 0.9761
# Epoch 13/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0656 - accuracy: 0.9792 - val_loss: 0.0934 - val_accuracy: 0.9753
# Epoch 14/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0677 - accuracy: 0.9783 - val_loss: 0.0834 - val_accuracy: 0.9771
# Epoch 15/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0643 - accuracy: 0.9800 - val_loss: 0.0900 - val_accuracy: 0.9761
# Epoch 16/20
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0600 - accuracy: 0.9807 - val_loss: 0.0906 - val_accuracy: 0.9764
# Epoch 17/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0569 - accuracy: 0.9817 - val_loss: 0.0879 - val_accuracy: 0.9769
# Epoch 18/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0547 - accuracy: 0.9825 - val_loss: 0.0880 - val_accuracy: 0.9771
# Epoch 19/20
# 329/329 [==============================] - 3s 10ms/step - loss: 0.0559 - accuracy: 0.9821 - val_loss: 0.0892 - val_accuracy: 0.9773
# Epoch 20/20
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0549 - accuracy: 0.9826 - val_loss: 0.0892 - val_accuracy: 0.9774

# %%
loss, acc = model.evaluate(x_test, y_test)
print("\nTest accuracy: %.1f%%" % (100.0 * acc))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0782 - accuracy: 0.9789
#
# Test accuracy: 97.9%

# %%
loss, acc = model.evaluate(x_train, y_train)
print("\nTest accuracy: %.1f%%" % (100.0 * acc))
# Out:
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0349 - accuracy: 0.9908
#
# Test accuracy: 99.1%

# %%
import matplotlib.pyplot as plt


epochs = np.arange(0, len(H.history["loss"]))
plt.figure(figsize=(10,8))
plt.style.use("ggplot")


# plot training and validation loss
plt.style.use("ggplot")
plt.plot(epochs, H.history["loss"], label="train_loss")
plt.plot(epochs, H.history["val_loss"], label="val_loss")
plt.title("Training Vs Validation Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()

# %% [markdown]
# # Assignment
#
# Combine both L2 and Dropout and report your findings.
# 1. Did you experience any change in performance?
# 2. Did the error reduced?
# 3. Were there any significant improvement in the validation loss as against the training loss?
